# %%
import json
import pandas as pd
from pathlib import Path

data_dir = Path('/kaggle/input/datasets/syedjaffarrazakazmi/smart-om')  
for item in sorted(data_dir.rglob('*')):
    if item.is_file():
        print(item)
# Out:
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/5 - DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/6 - DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/7 - DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/8 - DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/9 - DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00001_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00004_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00005_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00006_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00006_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00007_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00007_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00008_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00008_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00009_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00009_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00010_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00010_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00011_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00012_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00012_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00013_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00013_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00014_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00014_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00015_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00015_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00016_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00016_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00017_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00017_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00018_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00018_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00019_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00019_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00020_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00020_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00021_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00021_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000230_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000232_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000233_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000234_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000235_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000237_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000239_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00024-1_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000241_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000247_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00025-1_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000252_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000254_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA000256_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00026_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00027-1_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00027_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00028_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00034_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00035_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00036_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00037_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00038_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00039_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00040_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00041_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00042_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00044_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00045_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00047_R_DT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00050_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00051_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00052_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00053_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00054_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00055_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00056_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00057_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00058_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00059_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00060_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00061_R-DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00062_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00063_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00064_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00065_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00066_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00067_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00069_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00070_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00071_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00072_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00073_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00074_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00075_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00076_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00080_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00081_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00082_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00086_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00087_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00089_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00090_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00092_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00104_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00105_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00106_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00107_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00108_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00109_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00110_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00111_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00112_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00113_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00114_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00115_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00116_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00117_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00125_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00126_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00127_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00128_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00129_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00130_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00131_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00132_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00133_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00134_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00135_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00136_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00137_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00138_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00141_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00142_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00143_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00144_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00145_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00146_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00147_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00148_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00151_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00152_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00154_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00155_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00156_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00157_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00158_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00159_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00160_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00161_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00163_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00164_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00165_R-DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00166_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00167_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00168_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00169_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00170_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00171_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00172_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00173_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00174_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00176_W-DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00177_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00178_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00179_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00180_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00181_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00182_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00183_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00184_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00185_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00186_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00187_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00189_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00190_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00191_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00192_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00193_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00194_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00196_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00197-R-DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00199_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00202_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00203_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00204_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00205_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00206_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00207_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00210_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00212_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00214_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00215_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00216_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00217_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00218_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00219_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00220_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00221_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00222_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00223_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00224_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00225_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00228_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00229_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00231_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00236_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00238_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00240_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00242_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00244_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00245_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00246_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00248_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00250_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00251_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00253_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00255_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00257_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00258_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00259_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00260_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00261_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00262_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00263_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00264_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00265_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00266_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00267_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00268_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00269_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00270_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00271_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00273_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00274_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00275_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00276_W_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00277_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00278_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00281_W_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00283_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00284_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00285_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00286_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00287_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00288_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00289_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00290_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00291_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00292_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00293_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00294_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00295_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00296_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00297_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00298_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00299_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00300_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00301_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00303_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00304_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00305_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00306_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00307_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00308_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00309_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00310_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00311_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00313_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00314_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00315_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00316_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00317_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00318_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00319_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00320_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00321_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00322_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00323_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00324_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00325_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00326_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00327_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00329_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00330_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00331_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00332_R_DT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00333_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00334_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00335_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00336_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00337_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00338_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00339_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00341_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00343_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00344_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00345_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/01. Dorsal tongue/SMITA00346_R_DT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/5 - VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/6 - VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/8 -VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/9 - VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00001_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00002_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00004_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00005_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00006_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00006_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00007_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00007_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00008_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00008_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00009_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00010_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00010_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00011_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00011_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00012_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00012_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00014_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00014_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00015_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00015_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00016_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00016_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00017_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00017_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00018_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00018_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00019_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00019_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00020_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00020_W_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00021_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00021_W_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000221_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00022_R_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000230_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000232_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000233_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000234_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000235_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000237_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000239_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00024-1_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000243_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000247_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000249_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00025-1_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000252_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA000254_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00027-1_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00027_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00028_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00031_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00034_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00035_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00037_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00038_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00040_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00041_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00042_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00044_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00045_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00046_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00047_R_VT.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00050_R_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00051_R_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00052_R_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00053_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00054_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00055_R_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00056_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00057_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00058_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00059_R_VT.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00061_R_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00063_R_VT.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/01. Normal/01. Unannotated/02. Ventral tongue/SMITA00064_R_VT.jpg
# ...
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/01. Unannotated/08. Lower arch/Ca 6.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/6026_region.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/6765_region.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/6766_region.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/7059_region.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/CA 2_region.jpg.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/Ca 10.JPEG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/Ca 2.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/Ca 7.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/02. Ventral tongue/Ca3.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/03. Left buccal mucosa/6098_region.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/03. Left buccal mucosa/Ca 9.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/04. Right buccal mucosa/6095_region.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/04. Right buccal mucosa/6099_Region.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/04. Right buccal mucosa/Ca 4_region.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/04. Right buccal mucosa/Ca 8.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/06. Lower lip/7252_region.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/07. Upper arch/Ca 1.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/07. Upper arch/Ca 5.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/08. Lower arch/Ca 4.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/08. Lower arch/Ca 6.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/6026_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/6095_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/6098_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/6099_Region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/6765_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/6766_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/7059_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/7252_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/CA 2_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 10 _ REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 2 _ REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 3 _REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 4_REGION (2).json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 4_region.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 5 _ REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 6 _ REGIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 7_ REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 8 _REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca 9 _ REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/02. Region annotation/Region Json/Ca1 _ REGION.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/6026_full.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/6765_full.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/6766_full.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/7059_full.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/Ca 10.JPEG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/Ca 2.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/Ca 2_full.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/Ca 7.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/02. Ventral tongue/Ca3.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/03. Left buccal mucosa/6098_full.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/03. Left buccal mucosa/Ca 9.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/04. Right buccal mucosa/6095_full.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/04. Right buccal mucosa/6099_full.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/04. Right buccal mucosa/Ca 4_full.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/04. Right buccal mucosa/Ca 8.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/06. Lower lip/7252_full.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/07. Upper arch/Ca 1.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/07. Upper arch/Ca 5.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/08. Lower arch/Ca 4.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/08. Lower arch/Ca 6.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/6026_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/6095_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/6098_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/6099_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/6765_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/6766_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/7059_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/7252_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 10 _FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 2_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 3 _FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 4_FULL (2).json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 4_full.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 5_ FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 6 _FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 7_ FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 8 _FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca 9 _ FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca1 _FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/03. Full annotation/Full Json/Ca2_FULL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/6026_lesion.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/6765_lesion.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/6766_lesion.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/7059_lesion.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/Ca 10.JPEG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/Ca 2.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/Ca 2_lesion.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/Ca 7.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/02. Ventral tongue/Ca3.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/03. Left buccal mucosa/6098_lesion.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/03. Left buccal mucosa/Ca 9.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/04. Right buccal mucosa/6095_lesion.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/04. Right buccal mucosa/6099_lesion.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/04. Right buccal mucosa/Ca 4_lesion.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/04. Right buccal mucosa/Ca 8.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/06. Lower lip/7252_lesion.jpeg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/07. Upper arch/Ca 1.JPG
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/07. Upper arch/Ca 5.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/08. Lower arch/Ca 4.jpg
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/08. Lower arch/Ca 6.png
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/6026_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/6095_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/6098_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/6099_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/6765_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/6766_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/7059_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/7252_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 10 _LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 2_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 3 _LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 4_LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 4_lesion.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 5 _ LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 6_ LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 7_ LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 8 _LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca 9 _ LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca1 _LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/04. Oral Cancer/04. Lesion annotation/Lesion Json/Ca2_LESIONAL.json
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/Descriptors/01. Descriptors_for_region_annotation.xlsx
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/Descriptors/02. Descriptors_for_full_annotation.xlsx
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/Descriptors/03. Descriptors_for_lesion_annotation.xlsx
# /kaggle/input/datasets/syedjaffarrazakazmi/smart-om/SMART-OM/Metadata/Patient_s Metadata.xlsx

# %%
from pathlib import Path
from PIL import Image
import pandas as pd
import re

DATA_DIR = Path('/kaggle/input/datasets/syedjaffarrazakazmi/smart-om')
DATASET_NAME = 'smart_om'


valid_extensions = {'.jpg', '.jpeg', '.png', '.JPG', '.JPEG'}

image_records = []

# Scan all image files
for file_path in DATA_DIR.rglob('*'):
    if file_path.is_file() and file_path.suffix in valid_extensions:
        parts = file_path.parts
        
        
        condition = parts[6] if len(parts) > 6 else 'Unknown'       # e.g., '01. Normal'
        annotation_group = parts[7] if len(parts) > 7 else 'Unknown' # e.g., '01. Unannotated'
        anatomical_site = parts[8] if len(parts) > 8 else 'Unknown'  # e.g., '01. Dorsal tongue'
        
        filename = file_path.name
        stem = file_path.stem
        
        # Extract Patient ID (e.g., SMITA00001 from SMITA00001_W_DT)
        patient_match = re.match(r'^(SMITA\d+|\d+)', stem)
        patient_id = patient_match.group(1) if patient_match else 'Unknown'

        # Extract capture/light type if present (e.g., _W_ for White light, _R_ for Regular)
        capture_type = 'Unknown'
        if '_W_' in filename or '_W-' in filename:
            capture_type = 'White Light'
        elif '_R_' in filename or '_R-' in filename:
            capture_type = 'Regular'

        image_records.append({
            'source_dataset': DATASET_NAME,
            'file_name': filename,
            'file_path': str(file_path),
            'image_stem': stem,
            'patient_id': patient_id,
            'condition_category': condition,
            'annotation_group': annotation_group,
            'anatomical_site': anatomical_site,
            'capture_type': capture_type
        })

df_images = pd.DataFrame(image_records)
print(f"Total images cataloged: {len(df_images)}")
print(df_images.head())
# Out:
# Total images cataloged: 7731
#   source_dataset               file_name  \
# 0       smart_om    SMITA00187_W_VT.jpeg
# 1       smart_om    SMITA00187_W_UL.jpeg
# 2       smart_om     SMITA00274_W_LB.jpg
# 3       smart_om  SMITA000233_R_LB2.jpeg
# 4       smart_om    SMITA00262_R_LB.jpeg
#
#                                            file_path         image_stem  \
# 0  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_VT
# 1  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_UL
# 2  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00274_W_LB
# 3  /kaggle/input/datasets/syedjaffarrazakazmi/sma...  SMITA000233_R_LB2
# 4  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00262_R_LB
#
#     patient_id condition_category annotation_group        anatomical_site  \
# 0   SMITA00187           SMART-OM         03. OPMD  04. Lesion annotation
# 1   SMITA00187           SMART-OM         03. OPMD  04. Lesion annotation
# 2   SMITA00274           SMART-OM         03. OPMD  04. Lesion annotation
# 3  SMITA000233           SMART-OM         03. OPMD  04. Lesion annotation
# 4   SMITA00262           SMART-OM         03. OPMD  04. Lesion annotation
#
#   capture_type
# 0  White Light
# 1  White Light
# 2  White Light
# 3      Regular
# 4      Regular

# %%
widths = []
heights = []
is_valid = []

print("Extracting image resolutions and verifying files...")

for idx, row in df_images.iterrows():
    try:
        with Image.open(row['file_path']) as img:
            w, h = img.size
            widths.append(w)
            heights.append(h)
            is_valid.append(True)
    except Exception as e:
        widths.append(None)
        heights.append(None)
        is_valid.append(False)

df_images['width'] = widths
df_images['height'] = heights
df_images['is_valid_image'] = is_valid

print(f"Done! Valid images: {df_images['is_valid_image'].sum()} / {len(df_images)}")
print("\n--- Image Dimensions Summary ---")
print(df_images[['width', 'height']].describe())
# Out:
# Extracting image resolutions and verifying files...
# Done! Valid images: 7731 / 7731
#
# --- Image Dimensions Summary ---
#              width       height
# count  7731.000000  7731.000000
# mean    908.133101   708.906480
# std     382.565627   314.918927
# min     211.000000   143.000000
# 25%     594.000000   519.000000
# 50%     870.000000   599.000000
# 75%    1060.500000   815.500000
# max    2268.000000  4032.000000

# %%
import json
import pandas as pd
from pathlib import Path

annotation_records = []
json_files = list(DATA_DIR.rglob('*.json'))

print(f"Scanning and parsing {len(json_files)} VIA JSON files...")

for json_path in json_files:
    try:
        with open(json_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        img_metadata = data.get('_via_img_metadata', {})
        
        for via_id, entry in img_metadata.items():
            filename = entry.get('filename', '')
            stem = Path(filename).stem if filename else json_path.stem.replace('_Lesion', '').replace('_region', '').replace('_full', '')
            
            regions = entry.get('regions', [])
            for region in regions:
                shape = region.get('shape_attributes', {})
                region_attr = region.get('region_attributes', {})
                
                shape_type = shape.get('name', 'unknown')
                points_x = shape.get('all_points_x', [])
                points_y = shape.get('all_points_y', [])
                
                # Compute bounding box [xmin, ymin, xmax, ymax] and area
                xmin = min(points_x) if points_x else None
                xmax = max(points_x) if points_x else None
                ymin = min(points_y) if points_y else None
                ymax = max(points_y) if points_y else None
                bbox_width = (xmax - xmin) if (xmin is not None and xmax is not None) else None
                bbox_height = (ymax - ymin) if (ymin is not None and ymax is not None) else None
                
                # Determine region label
                label = 'lesion_or_region'
                if region_attr:
                    label = next(iter(region_attr.values()), label)
                
                annotation_records.append({
                    'json_file': json_path.name,
                    'json_path': str(json_path),
                    'image_filename': filename,
                    'image_stem': stem,
                    'shape_type': shape_type,
                    'num_points': len(points_x),
                    'label': label,
                    'xmin': xmin,
                    'ymin': ymin,
                    'xmax': xmax,
                    'ymax': ymax,
                    'bbox_width': bbox_width,
                    'bbox_height': bbox_height
                })
    except Exception as e:
        print(f"Error reading {json_path.name}: {e}")

df_annotations = pd.DataFrame(annotation_records)

print(f"\nDone! Extracted {len(df_annotations)} region annotations.")
print(df_annotations.head())
# Out:
# Scanning and parsing 1058 VIA JSON files...
# Error reading SMITA00212_R_full.json: 'NoneType' object has no attribute 'get'
# Error reading SMITA00028_R_region.json: 'NoneType' object has no attribute 'get'
# Error reading SMITA00028_R_full.json: 'NoneType' object has no attribute 'get'
#
# Done! Extracted 37943 region annotations.
#                    json_file  \
# 0  SMITA000252_R_Lesion.json
# 1   SMITA00010_W_Lesion.json
# 2   SMITA00010_W_Lesion.json
# 3   SMITA00262_R_Lesion.json
# 4   SMITA00262_R_Lesion.json
#
#                                            json_path         image_filename  \
# 0  /kaggle/input/datasets/syedjaffarrazakazmi/sma...  SMITA000252_R_LB.jpeg
# 1  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00010_W_LB.jpg
# 2  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00010_W_LB.jpg
# 3  /kaggle/input/datasets/syedjaffarrazakazmi/sma...   SMITA00262_R_LB.jpeg
# 4  /kaggle/input/datasets/syedjaffarrazakazmi/sma...  SMITA00262_R_RB1.jpeg
#
#          image_stem shape_type  num_points             label   xmin   ymin  \
# 0  SMITA000252_R_LB    polygon          57  lesion_or_region    0.0  298.0
# 1   SMITA00010_W_LB    polygon           6  lesion_or_region  127.0  434.0
# 2   SMITA00010_W_LB    polygon           7  lesion_or_region  936.0   16.0
# 3   SMITA00262_R_LB    polygon          91  lesion_or_region    0.0    4.0
# 4  SMITA00262_R_RB1    polygon         114  lesion_or_region   82.0   70.0
#
#      xmax    ymax  bbox_width  bbox_height
# 0   621.0  1143.0       621.0        845.0
# 1   546.0  1075.0       419.0        641.0
# 2  1352.0   990.0       416.0        974.0
# 3  1048.0   937.0      1048.0        933.0
# 4  1008.0  1230.0       926.0       1160.0

# %%
# Aggregate annotation metrics per image stem
if not df_annotations.empty:
    ann_summary = df_annotations.groupby('image_stem').agg(
        annotation_count=('shape_type', 'count'),
        total_annotated_points=('num_points', 'sum')
    ).reset_index()
    
    # Merge back into the image metadata DataFrame
    standardized_df = df_images.merge(ann_summary, on='image_stem', how='left')
    standardized_df['annotation_count'] = standardized_df['annotation_count'].fillna(0).astype(int)
    standardized_df['total_annotated_points'] = standardized_df['total_annotated_points'].fillna(0).astype(int)
else:
    standardized_df = df_images.copy()
    standardized_df['annotation_count'] = 0
    standardized_df['total_annotated_points'] = 0

print(f"Final dataset rows: {len(standardized_df)}")
print(f"Annotated images: {(standardized_df['annotation_count'] > 0).sum()} / {len(standardized_df)}")

print("\n--- Distribution by Condition Category ---")
print(standardized_df['condition_category'].value_counts())

print("\n--- Distribution by Anatomical Site ---")
print(standardized_df['anatomical_site'].value_counts())

print("\n--- Standardized Dataset Preview ---")
print(standardized_df.head())
# Out:
# Final dataset rows: 7731
# Annotated images: 7015 / 7731
#
# --- Distribution by Condition Category ---
# condition_category
# SMART-OM    7731
# Name: count, dtype: int64
#
# --- Distribution by Anatomical Site ---
# anatomical_site
# 02. Region annotation    2469
# 03. Full annotation      2469
# 01. Unannotated          2469
# 04. Lesion annotation     324
# Name: count, dtype: int64
#
# --- Standardized Dataset Preview ---
#   source_dataset               file_name  \
# 0       smart_om    SMITA00187_W_VT.jpeg
# 1       smart_om    SMITA00187_W_UL.jpeg
# 2       smart_om     SMITA00274_W_LB.jpg
# 3       smart_om  SMITA000233_R_LB2.jpeg
# 4       smart_om    SMITA00262_R_LB.jpeg
#
#                                            file_path         image_stem  \
# 0  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_VT
# 1  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_UL
# 2  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00274_W_LB
# 3  /kaggle/input/datasets/syedjaffarrazakazmi/sma...  SMITA000233_R_LB2
# 4  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00262_R_LB
#
#     patient_id condition_category annotation_group        anatomical_site  \
# 0   SMITA00187           SMART-OM         03. OPMD  04. Lesion annotation
# 1   SMITA00187           SMART-OM         03. OPMD  04. Lesion annotation
# 2   SMITA00274           SMART-OM         03. OPMD  04. Lesion annotation
# 3  SMITA000233           SMART-OM         03. OPMD  04. Lesion annotation
# 4   SMITA00262           SMART-OM         03. OPMD  04. Lesion annotation
#
#   capture_type  width  height  is_valid_image  annotation_count  \
# 0  White Light    385     410            True                14
# 1  White Light    562     221            True                 7
# 2  White Light    526     519            True                17
# 3      Regular    635     599            True                25
# 4      Regular    729     599            True                17
#
#    total_annotated_points
# 0                     103
# 1                      48
# 2                     190
# 3                     925
# 4                     721

# %%
# 1. Reassign condition and annotation group accurately
standardized_df['clinical_condition'] = standardized_df['annotation_group']
standardized_df['annotation_stage'] = standardized_df['anatomical_site']

# 2. Map anatomical site codes from file stems
site_code_map = {
    'DT': 'Dorsal tongue',
    'VT': 'Ventral tongue',
    'LB': 'Left buccal mucosa',
    'RB': 'Right buccal mucosa',
    'UL': 'Upper lip',
    'LL': 'Lower lip',
    'UA': 'Upper arch',
    'LA': 'Lower arch'
}

def extract_site(stem):
    for code, full_name in site_code_map.items():
        if f'_{code}' in stem or f'-{code}' in stem or stem.endswith(code):
            return full_name
    return 'Other'

standardized_df['oral_site'] = standardized_df['image_stem'].apply(extract_site)

# Drop redundant raw columns
columns_to_keep = [
    'source_dataset', 'file_name', 'file_path', 'image_stem', 'patient_id',
    'clinical_condition', 'annotation_stage', 'oral_site', 'capture_type',
    'width', 'height', 'is_valid_image', 'annotation_count', 'total_annotated_points'
]
standardized_df = standardized_df[columns_to_keep]

print("--- Clinical Conditions ---")
print(standardized_df['clinical_condition'].value_counts())

print("\n--- Oral Sites ---")
print(standardized_df['oral_site'].value_counts())

print("\n--- Annotation Stages ---")
print(standardized_df['annotation_stage'].value_counts())
# Out:
# --- Clinical Conditions ---
# clinical_condition
# 01. Normal                   6435
# 02. Variation from normal     716
# 03. OPMD                      500
# 04. Oral Cancer                80
# Name: count, dtype: int64
#
# --- Oral Sites ---
# oral_site
# Left buccal mucosa     1094
# Right buccal mucosa    1088
# Dorsal tongue          1010
# Lower lip               976
# Ventral tongue          906
# Upper arch              876
# Lower arch              867
# Upper lip               826
# Other                    88
# Name: count, dtype: int64
#
# --- Annotation Stages ---
# annotation_stage
# 02. Region annotation    2469
# 03. Full annotation      2469
# 01. Unannotated          2469
# 04. Lesion annotation     324
# Name: count, dtype: int64

# %%
from pathlib import Path

# Paths for exported CSVs
meta_csv_path = Path('/kaggle/working/smart_om_standardized_images.csv')
ann_csv_path = Path('/kaggle/working/smart_om_polygon_annotations.csv')

# Export DataFrames
standardized_df.to_csv(meta_csv_path, index=False)
df_annotations.to_csv(ann_csv_path, index=False)

# Validation Checks
assert len(standardized_df) == 7731, "Total row count mismatch"
assert standardized_df['is_valid_image'].all(), "Corrupted images detected"
assert standardized_df['patient_id'].isna().sum() == 0, "Missing patient IDs"

print(f"Standardized metadata exported to: {meta_csv_path}")
print(f"Polygon annotations exported to: {ann_csv_path}")
print(f"Total images: {len(standardized_df)} | Unique patients: {standardized_df['patient_id'].nunique()}")
print("\nFinal Metadata Preview:")
print(standardized_df.head())
# Out:
# Standardized metadata exported to: /kaggle/working/smart_om_standardized_images.csv
# Polygon annotations exported to: /kaggle/working/smart_om_polygon_annotations.csv
# Total images: 7731 | Unique patients: 320
#
# Final Metadata Preview:
#   source_dataset               file_name  \
# 0       smart_om    SMITA00187_W_VT.jpeg
# 1       smart_om    SMITA00187_W_UL.jpeg
# 2       smart_om     SMITA00274_W_LB.jpg
# 3       smart_om  SMITA000233_R_LB2.jpeg
# 4       smart_om    SMITA00262_R_LB.jpeg
#
#                                            file_path         image_stem  \
# 0  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_VT
# 1  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_UL
# 2  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00274_W_LB
# 3  /kaggle/input/datasets/syedjaffarrazakazmi/sma...  SMITA000233_R_LB2
# 4  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00262_R_LB
#
#     patient_id clinical_condition       annotation_stage           oral_site  \
# 0   SMITA00187           03. OPMD  04. Lesion annotation      Ventral tongue
# 1   SMITA00187           03. OPMD  04. Lesion annotation           Upper lip
# 2   SMITA00274           03. OPMD  04. Lesion annotation  Left buccal mucosa
# 3  SMITA000233           03. OPMD  04. Lesion annotation  Left buccal mucosa
# 4   SMITA00262           03. OPMD  04. Lesion annotation  Left buccal mucosa
#
#   capture_type  width  height  is_valid_image  annotation_count  \
# 0  White Light    385     410            True                14
# 1  White Light    562     221            True                 7
# 2  White Light    526     519            True                17
# 3      Regular    635     599            True                25
# 4      Regular    729     599            True                17
#
#    total_annotated_points
# 0                     103
# 1                      48
# 2                     190
# 3                     925
# 4                     721

# %%
# Step 6 — Class distribution & Annotation categories
print("=== Annotation Shape Types ===")
print(df_annotations['shape_type'].value_counts())

print("\n=== Annotation Labels ===")
print(df_annotations['label'].value_counts())

print("\n=== Clinical Conditions ===")
print(standardized_df['clinical_condition'].value_counts())

print("\n=== Oral Anatomical Sites ===")
print(standardized_df['oral_site'].value_counts())

print("\n=== Capture Type (Lighting) ===")
print(standardized_df['capture_type'].value_counts())
# Out:
# === Annotation Shape Types ===
# shape_type
# polygon     21979
# rect        15116
# polyline      488
# ellipse       274
# circle         86
# Name: count, dtype: int64
#
# === Annotation Labels ===
# label
# lesion_or_region    37943
# Name: count, dtype: int64
#
# === Clinical Conditions ===
# clinical_condition
# 01. Normal                   6435
# 02. Variation from normal     716
# 03. OPMD                      500
# 04. Oral Cancer                80
# Name: count, dtype: int64
#
# === Oral Anatomical Sites ===
# oral_site
# Left buccal mucosa     1094
# Right buccal mucosa    1088
# Dorsal tongue          1010
# Lower lip               976
# Ventral tongue          906
# Upper arch              876
# Lower arch              867
# Upper lip               826
# Other                    88
# Name: count, dtype: int64
#
# === Capture Type (Lighting) ===
# capture_type
# Regular        6139
# White Light    1405
# Unknown         187
# Name: count, dtype: int64

# %%
# Step 7 — Patient-level distribution
patient_img_counts = standardized_df.groupby('patient_id').size()
print("Images per patient — min/max/median:",
      patient_img_counts.min(), patient_img_counts.max(), patient_img_counts.median())

print(f"\nTotal Unique Patients: {standardized_df['patient_id'].nunique()}")

print("\nPatients per Clinical Condition:")
print(standardized_df.groupby('clinical_condition')['patient_id'].nunique())

print("\nPatients per Oral Site:")
print(standardized_df.groupby('oral_site')['patient_id'].nunique())
# Out:
# Images per patient — min/max/median: 3 57 24.0
#
# Total Unique Patients: 320
#
# Patients per Clinical Condition:
# clinical_condition
# 01. Normal                   306
# 02. Variation from normal    112
# 03. OPMD                      65
# 04. Oral Cancer                9
# Name: patient_id, dtype: int64
#
# Patients per Oral Site:
# oral_site
# Dorsal tongue          303
# Left buccal mucosa     297
# Lower arch             281
# Lower lip              288
# Other                   12
# Right buccal mucosa    297
# Upper arch             277
# Upper lip              268
# Ventral tongue         282
# Name: patient_id, dtype: int64

# %%
# Step 8 — Resolution (Width / Height)
widths  = standardized_df['width'].dropna().tolist()
heights = standardized_df['height'].dropna().tolist()

print("Width  — min/max/median:", min(widths), max(widths), pd.Series(widths).median())
print("Height — min/max/median:", min(heights), max(heights), pd.Series(heights).median())

print("\n--- Image Resolution Summary Statistics ---")
print(standardized_df[['width', 'height']].describe())
# Out:
# Width  — min/max/median: 211 2268 870.0
# Height — min/max/median: 143 4032 599.0
#
# --- Image Resolution Summary Statistics ---
#              width       height
# count  7731.000000  7731.000000
# mean    908.133101   708.906480
# std     382.565627   314.918927
# min     211.000000   143.000000
# 25%     594.000000   519.000000
# 50%     870.000000   599.000000
# 75%    1060.500000   815.500000
# max    2268.000000  4032.000000

# %%
# Step 9 — Out-of-bounds bounding box & polygon validation
# Map image stems to their corresponding width and height
dims_map = dict(zip(standardized_df['image_stem'], zip(standardized_df['width'], standardized_df['height'])))

bad_annotations = []
overflow_records = []

for _, ann in df_annotations.iterrows():
    stem = ann['image_stem']
    if stem in dims_map:
        w, h = dims_map[stem]
        if w is not None and h is not None and ann['xmin'] is not None:
            overflow_x = max(0, ann['xmax'] - w)
            overflow_y = max(0, ann['ymax'] - h)
            neg_x = min(0, ann['xmin'])
            neg_y = min(0, ann['ymin'])
            
            if ann['xmin'] < 0 or ann['ymin'] < 0 or ann['xmax'] > w or ann['ymax'] > h:
                bad_annotations.append(ann)
                overflow_records.append({
                    'image_stem': stem,
                    'json_file': ann['json_file'],
                    'overflow_x': overflow_x,
                    'overflow_y': overflow_y,
                    'neg_x': neg_x,
                    'neg_y': neg_y
                })

print("Out-of-bounds annotations count:", len(bad_annotations))

if overflow_records:
    df_overflow = pd.DataFrame(overflow_records)
    print("Unique images affected:", df_overflow['image_stem'].nunique())
    print("\nOverflow stats (pixels):")
    print(df_overflow[['overflow_x', 'overflow_y', 'neg_x', 'neg_y']].describe())
else:
    print("All annotations fit within image dimensions.")
# Out:
# Out-of-bounds annotations count: 420
# Unique images affected: 140
#
# Overflow stats (pixels):
#        overflow_x   overflow_y  neg_x       neg_y
# count  420.000000   420.000000  420.0  420.000000
# mean   100.097619    72.350000    0.0   -0.019048
# std    184.549112   180.504646    0.0    0.181794
# min      0.000000     0.000000    0.0   -2.000000
# 25%      0.000000     1.000000    0.0    0.000000
# 50%      0.000000     1.000000    0.0    0.000000
# 75%    170.000000     8.500000    0.0    0.000000
# max    790.000000  1043.000000    0.0    0.000000

# %%
 # Step 10 — Check salvageability by swapping w and h
salvageable_stems = set()
truly_broken_stems = set()

affected_stems = set(df_overflow['image_stem'].unique())

for _, ann in df_annotations.iterrows():
    stem = ann['image_stem']
    if stem in affected_stems:
        w, h = dims_map[stem]
        if w is not None and h is not None and ann['xmin'] is not None:
            # Check if swapping w and h makes box valid (or within a 2px margin)
            if ann['xmin'] >= -2 and ann['ymin'] >= -2 and ann['xmax'] <= (h + 2) and ann['ymax'] <= (w + 2):
                salvageable_stems.add(stem)
            else:
                truly_broken_stems.add(stem)

print("Salvageable with rotation swap:", len(salvageable_stems - truly_broken_stems))
print("Requires coordinate clipping / edge adjustment:", len(truly_broken_stems))
# Out:
# Salvageable with rotation swap: 1
# Requires coordinate clipping / edge adjustment: 139

# %%
# Step 11 — Process images into clean working directory
import shutil
from PIL import Image
from pathlib import Path

output_image_dir = Path('/kaggle/working/smart_om_clean_images')
output_image_dir.mkdir(parents=True, exist_ok=True)

rotated_count = 0
copied_count = 0

# Stems that need 90-deg rotation
rotate_stems = salvageable_stems - truly_broken_stems

for idx, row in standardized_df.iterrows():
    src_path = Path(row['file_path'])
    dst_path = output_image_dir / row['file_name']
    
    if row['image_stem'] in rotate_stems:
        with Image.open(src_path) as im:
            rotated = im.rotate(90, expand=True)
            rotated.save(dst_path)
            dims_map[row['image_stem']] = rotated.size
            standardized_df.at[idx, 'width'] = rotated.size[0]
            standardized_df.at[idx, 'height'] = rotated.size[1]
        rotated_count += 1
    else:
        shutil.copy2(src_path, dst_path)
        copied_count += 1

print(f"Rotated images: {rotated_count}")
print(f"Copied images: {copied_count}")
print(f"Total processed: {rotated_count + copied_count}")


# Clip bounding box coordinates with safe dictionary access
clipped_count = 0

for idx, ann in df_annotations.iterrows():
    stem = ann['image_stem']
    dims = dims_map.get(stem)
    
    if dims is not None and ann['xmin'] is not None:
        w, h = dims
        if w is not None and h is not None:
            df_annotations.at[idx, 'xmin'] = max(0, ann['xmin'])
            df_annotations.at[idx, 'ymin'] = max(0, ann['ymin'])
            df_annotations.at[idx, 'xmax'] = min(w, ann['xmax'])
            df_annotations.at[idx, 'ymax'] = min(h, ann['ymax'])
            df_annotations.at[idx, 'bbox_width'] = df_annotations.at[idx, 'xmax'] - df_annotations.at[idx, 'xmin']
            df_annotations.at[idx, 'bbox_height'] = df_annotations.at[idx, 'ymax'] - df_annotations.at[idx, 'ymin']
            clipped_count += 1

print(f"Successfully clipped and aligned {clipped_count} annotation boundaries.")
# Out:
# Rotated images: 4
# Copied images: 7727
# Total processed: 7731
# Successfully clipped and aligned 37846 annotation boundaries.

# %%
# Step 12 — Out-of-bounds re-verification
bad_boxes_after = 0

for _, ann in df_annotations.iterrows():
    stem = ann['image_stem']
    dims = dims_map.get(stem)
    if dims is not None and ann['xmin'] is not None:
        w, h = dims
        if w is not None and h is not None:
            if ann['xmin'] < 0 or ann['ymin'] < 0 or ann['xmax'] > w or ann['ymax'] > h:
                bad_boxes_after += 1

print("Out-of-bounds annotations after fix:", bad_boxes_after)
assert bad_boxes_after == 0, "Fix incomplete: out-of-bounds coordinates remain."
print("Assertion Passed: All bounding coordinates are valid.")
# Out:
# Out-of-bounds annotations after fix: 0
# Assertion Passed: All bounding coordinates are valid.

# %%
# Step 12.5 — Visual check: original vs clipped boxes for trimmed images
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import random
from PIL import Image

# Collect the ORIGINAL (before-clip) box positions for the 139 trimmed images
original_boxes = {}
for ann in bad_annotations:
    stem = ann['image_stem']
    original_boxes.setdefault(stem, []).append((ann['xmin'], ann['ymin'], ann['xmax'], ann['ymax']))

# Pick a random sample of 6 trimmed images to look at
sample_stems = random.sample(list(truly_broken_stems), min(6, len(truly_broken_stems)))

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

for i, stem in enumerate(sample_stems):
    row = standardized_df[standardized_df['image_stem'] == stem].iloc[0]
    img = Image.open(output_image_dir / row['file_name'])

    ax = axes[i]
    ax.imshow(img)
    ax.set_title(stem, fontsize=10)
    ax.axis('off')

    # RED dashed = the original box, before it was trimmed
    for (xmin, ymin, xmax, ymax) in original_boxes.get(stem, []):
        ax.add_patch(patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                     linewidth=2, edgecolor='red', facecolor='none', linestyle='--'))

    # GREEN = the final box that got saved (after trimming)
    for _, crow in df_annotations[df_annotations['image_stem'] == stem].iterrows():
        ax.add_patch(patches.Rectangle((crow['xmin'], crow['ymin']),
                     crow['xmax'] - crow['xmin'], crow['ymax'] - crow['ymin'],
                     linewidth=2, edgecolor='lime', facecolor='none'))

plt.suptitle("Red dashed = original box | Green = final trimmed box", fontsize=12)
plt.tight_layout()
plt.show()

print(f"Showing 6 of {len(truly_broken_stems)} trimmed images.")
print("Check: does the green box still cover the lesion, or did trimming cut off a real part of it?")
# Out:
# Showing 6 of 139 trimmed images.
# Check: does the green box still cover the lesion, or did trimming cut off a real part of it?

# %%
# Step 13 — Export and final sanity checks
from pathlib import Path

# Export cleaned metadata and annotations
export_meta_path = Path('/kaggle/working/smart_om_standardized.csv')
export_ann_path = Path('/kaggle/working/smart_om_polygon_annotations_cleaned.csv')

standardized_df.to_csv(export_meta_path, index=False)
df_annotations.to_csv(export_ann_path, index=False)

print("Exported metadata shape:", standardized_df.shape)
print("Exported annotations shape:", df_annotations.shape)


assert standardized_df['file_path'].nunique() == len(standardized_df), "Duplicate image file paths found"
assert standardized_df['clinical_condition'].isna().sum() == 0, "Unmatched clinical conditions"
assert standardized_df['patient_id'].isna().sum() == 0, "Unmatched patient IDs"
assert standardized_df['is_valid_image'].all(), "Corrupted images detected"

print("\nAll assertions passed successfully!")
print("Columns:", standardized_df.columns.tolist())
standardized_df.head(5)
# Out:
# Exported metadata shape: (7731, 14)
# Exported annotations shape: (37943, 13)
#
# All assertions passed successfully!
# Columns: ['source_dataset', 'file_name', 'file_path', 'image_stem', 'patient_id', 'clinical_condition', 'annotation_stage', 'oral_site', 'capture_type', 'width', 'height', 'is_valid_image', 'annotation_count', 'total_annotated_points']
#   source_dataset               file_name  \
# 0       smart_om    SMITA00187_W_VT.jpeg
# 1       smart_om    SMITA00187_W_UL.jpeg
# 2       smart_om     SMITA00274_W_LB.jpg
# 3       smart_om  SMITA000233_R_LB2.jpeg
# 4       smart_om    SMITA00262_R_LB.jpeg
#
#                                            file_path         image_stem  \
# 0  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_VT
# 1  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00187_W_UL
# 2  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00274_W_LB
# 3  /kaggle/input/datasets/syedjaffarrazakazmi/sma...  SMITA000233_R_LB2
# 4  /kaggle/input/datasets/syedjaffarrazakazmi/sma...    SMITA00262_R_LB
#
#     patient_id clinical_condition       annotation_stage           oral_site  \
# 0   SMITA00187           03. OPMD  04. Lesion annotation      Ventral tongue
# 1   SMITA00187           03. OPMD  04. Lesion annotation           Upper lip
# 2   SMITA00274           03. OPMD  04. Lesion annotation  Left buccal mucosa
# 3  SMITA000233           03. OPMD  04. Lesion annotation  Left buccal mucosa
# 4   SMITA00262           03. OPMD  04. Lesion annotation  Left buccal mucosa
#
#   capture_type  width  height  is_valid_image  annotation_count  \
# 0  White Light    385     410            True                14
# 1  White Light    562     221            True                 7
# 2  White Light    526     519            True                17
# 3      Regular    635     599            True                25
# 4      Regular    729     599            True                17
#
#    total_annotated_points
# 0                     103
# 1                      48
# 2                     190
# 3                     925
# 4                     721
